# %% [markdown]
# <a href="https://colab.research.google.com/github/BHUMIKA-2110/Data-Analysis/blob/main/students_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Load Dataset**

# %%
import pandas as pd
df = pd.read_csv("student-mat.csv")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# **2. Explore & Clean Data**

# %% [markdown]
# Check missing values

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Remove duplicates

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %% [markdown]
# Dataset shape & data types

# %%
df.shape
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# **3. Data Analysis**

# %% [markdown]
# Average final grade (G3)

# %%
df["G3"].mean()
# Out:
# np.float64(10.415189873417722)

# %% [markdown]
# Study Time vs Final Grade

# %%
df.groupby("studytime")["G3"].mean()
# Out:
# studytime
# 1    10.047619
# 2    10.171717
# 3    11.400000
# 4    11.259259
# Name: G3, dtype: float64

# %% [markdown]
# Gender-wise Performance

# %%
df.groupby("sex")["G3"].mean()
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %% [markdown]
# **4. Data Visualization**

# %% [markdown]
# Histogram of Final Grades

# %%
import matplotlib.pyplot as plt
plt.hist(df["G3"], bins=10)
plt.xlabel("Final Grade (G3)")
plt.ylabel("Number of Students")
plt.title("Distribution of Final Grades")
plt.show()

# %% [markdown]
# Study Time vs Final Grade

# %%
plt.scatter(df["studytime"], df["G3"])
plt.xlabel("Study Time (1-4)")
plt.ylabel("Final Grade (G3)")
plt.title("Study Time vs Final Grade")
plt.show()

# %% [markdown]
# Gender vs Final Grade (Boxplot)

# %%
import seaborn as sns
sns.boxplot(x="sex", y="G3", data=df)
plt.xlabel("Gender")
plt.ylabel("Final Grade (G3)")
plt.title("Gender vs Final Grade (Boxplot)")
plt.show()

# %% [markdown]
# **CONCLUSION**
# The Student Performance dataset was successfully analyzed using Python as part of the Data Science internship task. The dataset was clean, with no missing values or duplicate records, allowing accurate analysis. Exploratory data analysis showed that students who dedicate more time to studying tend to achieve better academic results. Gender-based analysis indicated a slight performance advantage for female students. Visualizations such as histograms, scatter plots, and boxplots helped in identifying trends and understanding data distribution clearly. Overall, this task demonstrated the complete data analysis workflow, including data loading, cleaning, analysis, visualization, and interpretation using Python libraries like Pandas, Matplotlib, and Seaborn.
